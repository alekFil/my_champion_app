# %% [markdown]
# # Импорт библиотек

# %%
import joblib
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import os

# %%
from sklearn.multioutput import MultiOutputClassifier
from catboost import CatBoostClassifier
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
)
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler

from sklearn.metrics import (
    roc_auc_score,
    precision_score,
    recall_score,
    f1_score,
    roc_curve,
    confusion_matrix,
)
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import hamming_loss

# %%
tqdm.pandas()
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
RANDOM_STATE = 1206

# %% [markdown]
# # Загрузка данных

# %% [markdown]
# ## Справочная информация

# %%
file_path = "../data/mats/base_scores_dict.joblib"

if os.path.isfile(file_path):
    base_scores_dict = joblib.load(file_path)

# %%
base_scores_dict.head()
# Out:
#   item  base_score
# 0   1T         0.4
# 1   1S         0.4
# 2  1Lo         0.5
# 3  1Eu         0.5
# 4   1F         0.5

# %%
file_path = "../data/mats/nlp_dict.joblib"

if os.path.isfile(file_path):
    nlp_dict = joblib.load(file_path)

# %%
nlp_dict.head()
# Out:
#   item                                       nlp_item   embed_0   embed_1  \
# 0   1T                                 Single Toeloop  3.158019 -1.617936
# 1   1S                                 Single Salchow  3.601343 -2.698863
# 2  1Lo                                    Single Loop  5.122801 -4.158421
# 3  1Eu  Single Euler (only used in jump combinations)  0.762735 -3.136916
# 4   1F                                    Single Flip  4.872679 -4.149351
#
#     embed_2   embed_3   embed_4   embed_5   embed_6   embed_7   embed_8  \
# 0  0.396813 -1.733884  1.948211  0.765280 -4.662311  2.644467  1.162508
# 1 -0.136379 -0.407949 -1.530264 -2.107504 -2.906400  1.774684  0.182980
# 2 -2.667444  0.345399 -0.499262  0.415096 -2.308891  3.640449 -1.090383
# 3 -0.003426  0.913632 -0.219761 -0.314236  0.426446 -0.346271  2.761745
# 4 -1.611438  0.783791  0.614820 -0.363553 -3.880303  1.822208 -0.969000
#
#     embed_9
# 0  0.099441
# 1 -3.096374
# 2  2.599226
# 3  0.762287
# 4 -0.667879

# %% [markdown]
# ## Данные для моделирования

# %%
file_path = "../data/processed/final_data.joblib"

if os.path.isfile(file_path):
    final_data = joblib.load(file_path)

# %%
final_data.shape
# Out:
# (136126, 62)

# %%
final_data.columns
# Out:
# Index(['id', 'total_score_id', 'title', 'decrease', 'base_score', 'goe',
#        'avg_score', 'unit_id', 'tournament_id', 'base_score_total_scores',
#        'components_score', 'total_score', 'elements_score',
#        'decreasings_score', 'starting_place', 'place', 'segment_name', 'info',
#        'overall_place', 'overall_total_score', 'overall_place_str', 'color',
#        'school_id', 'date_start', 'date_end', 'origin_id', 'sequences',
#        'cascade', 'title_nlp', 'cascade_nlp', 'multiply',
#        'tournament_duration', 'start_month', 'end_month', 'start_day_of_week',
#        'end_day_of_week', 'start_is_weekend', 'end_is_weekend', 'start_season',
#        'end_season', 'tournament_year', 'units_with_experience', 'falls',
#        'components_score_per_element', 'custom_base_score',
#        'avg_overall_place_last_year', 'avg_overall_total_score_last_year',
#        'avg_components_score_last_year', 'avg_place_last_year',
#        'avg_elements_score_last_year', 'avg_decreasings_score_last_year',
#        'avg_total_score_last_year', 'avg_falls_last_year',
#        'target_clear_element', 'difficulty', 'perfect_element', 'q_element',
#        'e_element', 'l_element', 'll_element', 'h_element', 'v_element'],
#       dtype='object')

# %%
file_path = "../data/processed/final_elements_data.joblib"

if os.path.isfile(file_path):
    final_elements_data = joblib.load(file_path)

# %%
final_elements_data.shape
# Out:
# (168745, 92)

# %% [markdown]
# ## Валидационные данные

# %%
file_path = "../data/processed/valid_unit_data.joblib"

if os.path.isfile(file_path):
    valid_unit_data = joblib.load(file_path)

# %%
file_path = "../data/processed/test_unit_data.joblib"

if os.path.isfile(file_path):
    test_unit_data = joblib.load(file_path)

# %%
file_path = "../data/processed/final_test_unit_data.joblib"

if os.path.isfile(file_path):
    final_test_unit_data = joblib.load(file_path)

# %%
file_path = "../data/processed/valid_unit_elements_data.joblib"

if os.path.isfile(file_path):
    valid_unit_elements_data = joblib.load(file_path)

# %%
file_path = "../data/processed/test_unit_elements_data.joblib"

if os.path.isfile(file_path):
    test_unit_elements_data = joblib.load(file_path)

# %%
file_path = "../data/processed/final_test_unit_elements_data.joblib"

if os.path.isfile(file_path):
    final_test_unit_elements_data = joblib.load(file_path)

# %%
file_path = "../data/temp/results_model_two.joblib"

if os.path.isfile(file_path):
    results_model_two = joblib.load(file_path)

# %% [markdown]
# # Описание идеи

# %% [markdown]
# Третья модель должна предсказывать ошибки на основании предсказанного GOE. Мультиклассовая классификация

# %% [markdown]
# # Моделирование на элементах

# %% [markdown]
# ## Исходные GOE

# %%
final_elements_data.columns
# Out:
# Index(['id', 'total_score_id', 'title', 'decrease', 'base_score', 'goe',
#        'avg_score', 'unit_id', 'tournament_id', 'base_score_total_scores',
#        'components_score', 'total_score', 'elements_score',
#        'decreasings_score', 'starting_place', 'place', 'segment_name', 'info',
#        'overall_place', 'overall_total_score', 'overall_place_str', 'color',
#        'school_id', 'date_start', 'date_end', 'origin_id', 'sequences',
#        'cascade', 'title_nlp', 'cascade_nlp', 'multiply',
#        'tournament_duration', 'start_month', 'end_month', 'start_day_of_week',
#        'end_day_of_week', 'start_is_weekend', 'end_is_weekend', 'start_season',
#        'end_season', 'tournament_year', 'units_with_experience', 'falls',
#        'components_score_per_element', 'custom_base_score',
#        'avg_overall_place_last_year', 'avg_overall_total_score_last_year',
#        'avg_components_score_last_year', 'avg_place_last_year',
#        'avg_elements_score_last_year', 'avg_decreasings_score_last_year',
#        'avg_total_score_last_year', 'avg_falls_last_year',
#        'target_clear_element', 'difficulty', 'perfect_element', 'q_element',
#        'e_element', 'l_element', 'll_element', 'h_element', 'v_element',
#        'element', 'attr_element', 'prev_element', 'attr_prev_element',
#        'next_element', 'attr_next_element', 'single_element',
#        'clear_prev_element', 'clear_next_element', 'perfect_attr_element',
#        'q_attr_element', 'e_attr_element', 'l_attr_element', 'll_attr_element',
#        'h_attr_element', 'v_attr_element', 'perfect_attr_prev_element',
#        'q_attr_prev_element', 'e_attr_prev_element', 'l_attr_prev_element',
#        'll_attr_prev_element', 'h_attr_prev_element', 'v_attr_prev_element',
#        'perfect_attr_next_element', 'q_attr_next_element',
#        'e_attr_next_element', 'l_attr_next_element', 'll_attr_next_element',
#        'h_attr_next_element', 'v_attr_next_element'],
#       dtype='object')

# %%
data_e8 = final_elements_data[
    [
        # "id",
        # "total_score_id",
        # "title",
        # "decrease",
        # "base_score",
        "goe",
        # "avg_score",
        # "unit_id",
        # "tournament_id",
        # "base_score_total_scores",
        # "components_score",
        # "total_score",
        # "elements_score",
        # "decreasings_score",
        # "starting_place",
        # "place",
        "segment_name",
        # "info",
        # "overall_place",
        # "overall_total_score",
        # "overall_place_str",
        "color",
        "school_id",
        # "date_start",
        # "date_end",
        "origin_id",
        # "sequences",
        # "cascade",
        # "title_nlp",
        # "cascade_nlp",
        "multiply",
        "tournament_duration",
        "start_month",
        "end_month",
        "start_day_of_week",
        "end_day_of_week",
        "start_is_weekend",
        "end_is_weekend",
        "start_season",
        "end_season",
        "tournament_year",
        # "units_with_experience",
        "falls",
        # "components_score_per_element",
        # "custom_base_score",
        "avg_overall_place_last_year",
        "avg_overall_total_score_last_year",
        "avg_components_score_last_year",
        "avg_place_last_year",
        "avg_elements_score_last_year",
        "avg_decreasings_score_last_year",
        "avg_total_score_last_year",
        "avg_falls_last_year",
        "target_clear_element",
        "difficulty",
        # "perfect_element",
        # "q_element",
        # "e_element",
        # "l_element",
        # "ll_element",
        # "h_element",
        # "v_element",
        "element",
        # "attr_element",
        "prev_element",
        # "attr_prev_element",
        "next_element",
        # "attr_next_element",
        "single_element",
        # "clear_prev_element",
        # "clear_next_element",
        "perfect_attr_element",
        "q_attr_element",
        "e_attr_element",
        "l_attr_element",
        "ll_attr_element",
        "h_attr_element",
        "v_attr_element",
        "perfect_attr_prev_element",
        "q_attr_prev_element",
        "e_attr_prev_element",
        "l_attr_prev_element",
        "ll_attr_prev_element",
        "h_attr_prev_element",
        "v_attr_prev_element",
        "perfect_attr_next_element",
        "q_attr_next_element",
        "e_attr_next_element",
        "l_attr_next_element",
        "ll_attr_next_element",
        "h_attr_next_element",
        "v_attr_next_element",
    ]
].copy()
data_e8.shape
# Out:
# (168745, 52)

# %%
data_e8.duplicated(keep="first").sum()
# Out:
# 791

# %% [markdown]
# ### Разделение данных

# %%
X = data_e8.drop(
    [
        "perfect_attr_element",
        "q_attr_element",
        "e_attr_element",
        "l_attr_element",
        "ll_attr_element",
        "h_attr_element",
        "v_attr_element",
    ],
    axis=1,
)
y = data_e8[
    [
        "perfect_attr_element",
        "q_attr_element",
        "e_attr_element",
        "l_attr_element",
        "ll_attr_element",
        "h_attr_element",
        "v_attr_element",
    ]
]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, shuffle=False, random_state=1206
)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (126558, 45)
# (126558, 7)
# (42187, 45)
# (42187, 7)

# %% [markdown]
# ### Моделирование

# %%
category_columns = [
    # "id",
    # "total_score_id",
    # "title",
    # "decrease",
    # "base_score",
    # "goe",
    # "avg_score",
    # "unit_id",
    # "tournament_id",
    # "base_score_total_scores",
    # "components_score",
    # "total_score",
    # "elements_score",
    # "decreasings_score",
    # "starting_place",
    # "place",
    "segment_name",
    # "info",
    # "overall_place",
    # "overall_total_score",
    # "overall_place_str",
    "color",
    "school_id",
    # "date_start",
    # "date_end",
    "origin_id",
    # "sequences",
    # "cascade",
    # "title_nlp",
    # "cascade_nlp",
    "multiply",
    # "tournament_duration",
    "start_month",
    "end_month",
    "start_day_of_week",
    "end_day_of_week",
    "start_is_weekend",
    "end_is_weekend",
    "start_season",
    "end_season",
    "tournament_year",
    # "units_with_experience",
    "falls",
    # "components_score_per_element",
    # "custom_base_score",
    # "avg_overall_place_last_year",
    # "avg_overall_total_score_last_year",
    # "avg_components_score_last_year",
    # "avg_place_last_year",
    # "avg_elements_score_last_year",
    # "avg_decreasings_score_last_year",
    # "avg_total_score_last_year",
    # "avg_falls_last_year",
    "target_clear_element",
    # "difficulty",
    # "perfect_element",
    # "q_element",
    # "e_element",
    # "l_element",
    # "ll_element",
    # "h_element",
    # "v_element",
    "element",
    # "attr_element",
    "prev_element",
    # "attr_prev_element",
    "next_element",
    # "attr_next_element",
    "single_element",
    # "clear_prev_element",
    # "clear_next_element",
    # "perfect_attr_element",
    # "q_attr_element",
    # "e_attr_element",
    # "l_attr_element",
    # "ll_attr_element",
    # "h_attr_element",
    # "v_attr_element",
    "perfect_attr_prev_element",
    "q_attr_prev_element",
    "e_attr_prev_element",
    "l_attr_prev_element",
    "ll_attr_prev_element",
    "h_attr_prev_element",
    "v_attr_prev_element",
    "perfect_attr_next_element",
    "q_attr_next_element",
    "e_attr_next_element",
    "l_attr_next_element",
    "ll_attr_next_element",
    "h_attr_next_element",
    "v_attr_next_element",
]

ohe_columns = [x for x in category_columns if x in X.columns]
scale_columns = [x for x in X.columns if x not in category_columns]

# %%
# Инициализация базового классификатора

base_classifier_e8 = CatBoostClassifier(
    verbose=50,
    n_estimators=50,
    cat_features=category_columns,
    random_state=RANDOM_STATE,
)

# Инициализация мультилейбл классификатора
multi_target_classifier_e8 = MultiOutputClassifier(base_classifier_e8, n_jobs=-1)

# Обучение модели
multi_target_classifier_e8.fit(X_train, y_train)
# Out:
# MultiOutputClassifier(estimator=<catboost.core.CatBoostClassifier object at 0x0000026E10900AD0>,
#                       n_jobs=-1)

# %%
y_pred_multi_target_e8 = multi_target_classifier_e8.predict(X_test)

# %%
y_proba_multi_target_e8 = multi_target_classifier_e8.predict_proba(X_test)

# %%
print(classification_report(y_test, y_pred_multi_target_e8))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     33340
#            1       0.69      0.33      0.44      2075
#            2       0.55      0.08      0.14       206
#            3       0.78      0.77      0.77      3699
#            4       0.90      0.70      0.79      1712
#            5       0.83      0.50      0.62      1137
#            6       1.00      1.00      1.00       461
#
#    micro avg       0.97      0.92      0.94     42630
#    macro avg       0.82      0.63      0.68     42630
# weighted avg       0.95      0.92      0.93     42630
#  samples avg       0.92      0.92      0.92     42630
# c:\Users\filat\Documents\projects\my_champion_app\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
hamming_loss_score = hamming_loss(y_test, y_pred_multi_target_e8)
print(f"Hamming Loss: {hamming_loss_score}")
# Out:
# Hamming Loss: 0.016589402964352594

# %%
# Получение важности признаков для каждого классификатора
feature_importances = []

for idx, classifier in enumerate(multi_target_classifier_e8.estimators_):
    importances = classifier.get_feature_importance()
    feature_importances.append(importances)
    print(f"Feature importances for label {idx}: {importances}")

# Рассчет среднего значения важности признаков по всем меткам
average_feature_importances = np.mean(feature_importances, axis=0)

# Создание DataFrame для отображения важности признаков
feature_importance_df = pd.DataFrame(
    {"feature": X_train.columns, "importance": average_feature_importances}
).sort_values(by="importance", ascending=False)

feature_importance_df
# Out:
# Feature importances for label 0: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 3.68262382e-01 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.78187679e-01
#  3.42139701e-01 6.29488498e-02 3.06448636e-01 9.04736449e-02
#  0.00000000e+00 9.86515391e+01 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00]
# Feature importances for label 1: [7.84778958e+00 1.39593455e-02 0.00000000e+00 3.66154755e-02
#  6.81805541e-02 7.21957328e-01 1.19866151e-01 8.91649949e-03
#  1.03445191e-04 1.94401646e-02 2.51946122e-02 0.00000000e+00
#  9.52522368e-02 2.66434017e-02 8.03664220e-07 7.22591167e-02
#  1.42437794e+00 2.31505739e-01 4.57023455e-01 2.31070504e-01
#  7.45390150e-01 1.37739403e-01 6.36157567e-01 2.20841075e-01
#  1.00469503e-01 8.02771202e+01 2.97488632e+00 4.15094144e-01
#  2.03433239e+00 7.74981615e-01 0.00000000e+00 1.45870839e-02
#  0.00000000e+00 0.00000000e+00 1.80330762e-02 2.34869413e-02
#  2.54993457e-02 0.00000000e+00 8.00880679e-02 1.20941285e-02
#  0.00000000e+00 7.45021671e-02 3.45404312e-02 0.00000000e+00
#  0.00000000e+00]
# Feature importances for label 2: [9.96899878e+00 3.61514510e-02 0.00000000e+00 0.00000000e+00
#  1.68752243e+00 2.21649167e+00 3.86336451e-01 3.19958434e-01
#  0.00000000e+00 7.37641893e-01 9.76621729e-02 7.23525573e-02
#  0.00000000e+00 9.45942243e-05 1.19723940e-01 4.59706597e-01
#  6.25053899e-01 2.38065092e-01 1.04273763e+00 1.22314812e+00
#  2.26950826e+00 3.93382486e-01 1.72123352e+00 1.24737727e+00
#  6.10068524e-01 4.48536703e+01 1.76111352e+01 7.11714068e+00
#  4.26839981e+00 1.92313272e-01 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.27599020e-01 1.80912978e-01
#  0.00000000e+00 1.17742215e-01 4.67251147e-02 1.11456517e-02
#  0.00000000e+00]
# Feature importances for label 3: [1.37387621e+01 6.57924518e-02 6.47089985e-02 2.49078067e-02
#  3.09962586e-01 3.92240892e-02 0.00000000e+00 2.29563321e-02
#  8.12120089e-03 9.34583867e-02 5.26806590e-02 1.84098588e-02
#  0.00000000e+00 2.11962155e-06 5.73530100e-03 1.78695726e-02
#  2.04268619e+00 7.39755663e-02 1.47872941e-01 3.40812581e-01
#  8.23301225e-01 5.50999343e-02 7.43736119e-01 4.27879905e-01
#  4.12908350e-02 7.26735403e+01 6.13645058e+00 9.28984726e-01
#  1.98507765e-01 6.37623363e-01 0.00000000e+00 1.90270295e-02
#  4.10585647e-02 2.97305796e-03 7.24171700e-02 0.00000000e+00
#  5.23457612e-03 0.00000000e+00 5.93481322e-02 9.25105622e-03
#  0.00000000e+00 1.96581731e-02 3.66787101e-02 0.00000000e+00
#  0.00000000e+00]
# Feature importances for label 4: [1.42212890e+01 4.64258825e-02 0.00000000e+00 7.50962185e-01
#  1.59385200e-02 5.99174918e-01 1.39634493e-02 1.78586758e-02
#  7.65115920e-04 5.96451344e-02 2.25610533e-02 0.00000000e+00
#  3.61592380e-02 2.18678368e-02 0.00000000e+00 7.68617983e-02
#  2.65820718e+00 2.65071562e-02 1.56458939e+00 2.42888209e-01
#  6.49814807e-01 1.20508041e-01 5.36477439e-01 1.86097397e-01
#  0.00000000e+00 5.86498138e+01 1.39562657e+01 8.38336815e-01
#  2.99190646e+00 1.29805990e+00 0.00000000e+00 8.08520951e-02
#  4.95410723e-02 0.00000000e+00 3.12131917e-02 5.99532855e-02
#  2.38800372e-02 0.00000000e+00 4.98442419e-02 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.01770959e-01 0.00000000e+00
#  0.00000000e+00]
# Feature importances for label 5: [6.97355937e+00 0.00000000e+00 7.06040344e-01 1.69029049e-01
#  7.20231558e-01 0.00000000e+00 1.66254568e-03 1.69927522e-04
#  5.14064489e-01 4.84564632e-03 3.27551359e-02 1.68272276e-01
#  0.00000000e+00 3.06102089e-01 1.36571862e-03 5.66209608e-02
#  6.52271623e-01 5.88648139e-01 4.98827707e+00 9.35785825e-01
#  1.44023163e+00 2.91026018e-01 8.07587190e-01 1.32054459e-01
#  3.08265600e-01 5.16931470e+01 5.43223251e+00 2.20604867e+01
#  1.55612561e-01 4.76319455e-01 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.54089667e-02 2.90909934e-01
#  0.00000000e+00 7.28841910e-02 4.13200826e-03 1.84933742e-09
#  0.00000000e+00]
# Feature importances for label 6: [4.68511143e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  5.52013946e-05 2.57454379e+01 1.93818074e-03 2.45632847e-02
#  2.15283641e-03 1.25626664e-10 6.29062750e-04 0.00000000e+00
#  0.00000000e+00 2.02472022e-05 6.18213612e-04 6.04275148e-02
#  2.01785068e-01 8.51012614e-01 2.32553586e-01 8.21161465e-02
#  5.37210113e-01 7.01072074e-07 3.56273084e-01 3.73547309e-01
#  1.82377964e-01 3.64445978e+01 1.87600557e+01 1.07327906e+01
#  0.00000000e+00 7.00051343e-01 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 2.46741877e-02
#  0.00000000e+00]
#                               feature  importance
# 25               target_clear_element   63.320490
# 26                         difficulty    9.267289
# 0                                 goe    8.205073
# 27                            element    6.013262
# 5                            multiply    4.241507
# 28                       prev_element    1.378394
# 18  avg_overall_total_score_last_year    1.204722
# 16                              falls    1.086340
# 20                avg_place_last_year    0.972514
# 22    avg_decreasings_score_last_year    0.729702
# 29                       next_element    0.582764
# 19     avg_components_score_last_year    0.462001
# 4                           origin_id    0.400270
# 23          avg_total_score_last_year    0.382610
# 17        avg_overall_place_last_year    0.287102
# 24                avg_falls_last_year    0.177496
# 21       avg_elements_score_last_year    0.151529
# 3                           school_id    0.140216
# 9                   start_day_of_week    0.130719
# 2                               color    0.110107
# 15                    tournament_year    0.106249
# 8                           end_month    0.075030
# 6                 tournament_duration    0.074824
# 39                q_attr_next_element    0.070453
# 7                         start_month    0.056346
# 13                       start_season    0.050676
# 38          perfect_attr_next_element    0.047470
# 41                l_attr_next_element    0.040684
# 11                   start_is_weekend    0.037005
# 10                    end_day_of_week    0.033069
# 42               ll_attr_next_element    0.031978
# 1                        segment_name    0.023190
# 12                     end_is_weekend    0.018773
# 14                         end_season    0.018206
# 34                l_attr_prev_element    0.017380
# 31          perfect_attr_prev_element    0.016352
# 32                q_attr_prev_element    0.012943
# 35               ll_attr_prev_element    0.011920
# 36                h_attr_prev_element    0.007802
# 43                h_attr_next_element    0.005117
# 33                e_attr_prev_element    0.000425
# 30                     single_element    0.000000
# 37                v_attr_prev_element    0.000000
# 40                e_attr_next_element    0.000000
# 44                v_attr_next_element    0.000000

# %% [markdown]
# ## Без GOE

# %%
data_e9 = final_elements_data[
    [
        # "id",
        # "total_score_id",
        # "title",
        # "decrease",
        # "base_score",
        # "goe",
        # "avg_score",
        # "unit_id",
        # "tournament_id",
        # "base_score_total_scores",
        # "components_score",
        # "total_score",
        # "elements_score",
        # "decreasings_score",
        # "starting_place",
        # "place",
        # "segment_name",
        # "info",
        # "overall_place",
        # "overall_total_score",
        # "overall_place_str",
        "color",
        "school_id",
        # "date_start",
        # "date_end",
        "origin_id",
        # "sequences",
        # "cascade",
        # "title_nlp",
        # "cascade_nlp",
        "multiply",
        "tournament_duration",
        "start_month",
        "end_month",
        "start_day_of_week",
        "end_day_of_week",
        "start_is_weekend",
        "end_is_weekend",
        "start_season",
        "end_season",
        "tournament_year",
        # "units_with_experience",
        "falls",
        # "components_score_per_element",
        # "custom_base_score",
        "avg_overall_place_last_year",
        "avg_overall_total_score_last_year",
        "avg_components_score_last_year",
        "avg_place_last_year",
        "avg_elements_score_last_year",
        "avg_decreasings_score_last_year",
        "avg_total_score_last_year",
        "avg_falls_last_year",
        # "target_clear_element",
        "difficulty",
        # "perfect_element",
        # "q_element",
        # "e_element",
        # "l_element",
        # "ll_element",
        # "h_element",
        # "v_element",
        "element",
        # "attr_element",
        "prev_element",
        # "attr_prev_element",
        "next_element",
        # "attr_next_element",
        "single_element",
        # "clear_prev_element",
        # "clear_next_element",
        "perfect_attr_element",
        "q_attr_element",
        "e_attr_element",
        "l_attr_element",
        "ll_attr_element",
        "h_attr_element",
        "v_attr_element",
        "perfect_attr_prev_element",
        "q_attr_prev_element",
        "e_attr_prev_element",
        "l_attr_prev_element",
        "ll_attr_prev_element",
        "h_attr_prev_element",
        "v_attr_prev_element",
        "perfect_attr_next_element",
        "q_attr_next_element",
        "e_attr_next_element",
        "l_attr_next_element",
        "ll_attr_next_element",
        "h_attr_next_element",
        "v_attr_next_element",
    ]
].copy()
data_e9.shape
# Out:
# (168745, 49)

# %%
data_e9.duplicated(keep="first").sum()
# Out:
# 5038

# %% [markdown]
# ### Разделение данных

# %%
X = data_e9.drop(
    [
        "perfect_attr_element",
        "q_attr_element",
        "e_attr_element",
        "l_attr_element",
        "ll_attr_element",
        "h_attr_element",
        "v_attr_element",
    ],
    axis=1,
)
y = data_e9[
    [
        "perfect_attr_element",
        "q_attr_element",
        "e_attr_element",
        "l_attr_element",
        "ll_attr_element",
        "h_attr_element",
        "v_attr_element",
    ]
]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, shuffle=False, random_state=1206
)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (126558, 42)
# (126558, 7)
# (42187, 42)
# (42187, 7)

# %% [markdown]
# ### Моделирование

# %%
category_columns = [
    # "id",
    # "total_score_id",
    # "title",
    # "decrease",
    # "base_score",
    # "goe",
    # "avg_score",
    # "unit_id",
    # "tournament_id",
    # "base_score_total_scores",
    # "components_score",
    # "total_score",
    # "elements_score",
    # "decreasings_score",
    # "starting_place",
    # "place",
    # "segment_name",
    # "info",
    # "overall_place",
    # "overall_total_score",
    # "overall_place_str",
    "color",
    "school_id",
    # "date_start",
    # "date_end",
    "origin_id",
    # "sequences",
    # "cascade",
    # "title_nlp",
    # "cascade_nlp",
    "multiply",
    # "tournament_duration",
    "start_month",
    "end_month",
    "start_day_of_week",
    "end_day_of_week",
    "start_is_weekend",
    "end_is_weekend",
    "start_season",
    "end_season",
    "tournament_year",
    # "units_with_experience",
    "falls",
    # "components_score_per_element",
    # "custom_base_score",
    # "avg_overall_place_last_year",
    # "avg_overall_total_score_last_year",
    # "avg_components_score_last_year",
    # "avg_place_last_year",
    # "avg_elements_score_last_year",
    # "avg_decreasings_score_last_year",
    # "avg_total_score_last_year",
    # "avg_falls_last_year",
    # "target_clear_element",
    # "difficulty",
    # "perfect_element",
    # "q_element",
    # "e_element",
    # "l_element",
    # "ll_element",
    # "h_element",
    # "v_element",
    "element",
    # "attr_element",
    "prev_element",
    # "attr_prev_element",
    "next_element",
    # "attr_next_element",
    "single_element",
    # "clear_prev_element",
    # "clear_next_element",
    # "perfect_attr_element",
    # "q_attr_element",
    # "e_attr_element",
    # "l_attr_element",
    # "ll_attr_element",
    # "h_attr_element",
    # "v_attr_element",
    "perfect_attr_prev_element",
    "q_attr_prev_element",
    "e_attr_prev_element",
    "l_attr_prev_element",
    "ll_attr_prev_element",
    "h_attr_prev_element",
    "v_attr_prev_element",
    "perfect_attr_next_element",
    "q_attr_next_element",
    "e_attr_next_element",
    "l_attr_next_element",
    "ll_attr_next_element",
    "h_attr_next_element",
    "v_attr_next_element",
]

ohe_columns = [x for x in category_columns if x in X.columns]
scale_columns = [x for x in X.columns if x not in category_columns]

# %%
# Инициализация базового классификатора

base_classifier_e9 = CatBoostClassifier(
    verbose=50,
    n_estimators=50,
    cat_features=category_columns,
    random_state=RANDOM_STATE,
)

# Инициализация мультилейбл классификатора
multi_target_classifier_e9 = MultiOutputClassifier(base_classifier_e9, n_jobs=-1)

# Обучение модели
multi_target_classifier_e9.fit(X_train, y_train)
# Out:
# MultiOutputClassifier(estimator=<catboost.core.CatBoostClassifier object at 0x0000026E7D7FEAE0>,
#                       n_jobs=-1)

# %%
y_pred_multi_target_e9 = multi_target_classifier_e9.predict(X_test)

# %%
y_proba_multi_target_e9 = multi_target_classifier_e9.predict_proba(X_test)

# %%
print(classification_report(y_test, y_pred_multi_target_e9))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91     33340
#            1       0.19      0.00      0.00      2075
#            2       0.00      0.00      0.00       206
#            3       0.47      0.09      0.15      3699
#            4       0.46      0.10      0.16      1712
#            5       0.09      0.00      0.01      1137
#            6       0.41      0.11      0.17       461
#
#    micro avg       0.85      0.76      0.80     42630
#    macro avg       0.35      0.18      0.20     42630
# weighted avg       0.75      0.76      0.73     42630
#  samples avg       0.77      0.77      0.77     42630
# c:\Users\filat\Documents\projects\my_champion_app\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# Показатели снизились, что ожидаемо. Оценим работу с расчетным GOE от Модели № 2.

# %% [markdown]
# ## С расчетным GOE

# %%
data_e10 = final_elements_data[
    [
        # "id",
        # "total_score_id",
        # "title",
        # "decrease",
        # "base_score",
        "goe",
        # "avg_score",
        # "unit_id",
        # "tournament_id",
        # "base_score_total_scores",
        # "components_score",
        # "total_score",
        # "elements_score",
        # "decreasings_score",
        # "starting_place",
        # "place",
        # "segment_name",
        # "info",
        # "overall_place",
        # "overall_total_score",
        # "overall_place_str",
        "color",
        "school_id",
        # "date_start",
        # "date_end",
        "origin_id",
        # "sequences",
        # "cascade",
        # "title_nlp",
        # "cascade_nlp",
        "multiply",
        "tournament_duration",
        "start_month",
        "end_month",
        "start_day_of_week",
        "end_day_of_week",
        "start_is_weekend",
        "end_is_weekend",
        "start_season",
        "end_season",
        "tournament_year",
        # "units_with_experience",
        "falls",
        # "components_score_per_element",
        # "custom_base_score",
        "avg_overall_place_last_year",
        "avg_overall_total_score_last_year",
        "avg_components_score_last_year",
        "avg_place_last_year",
        "avg_elements_score_last_year",
        "avg_decreasings_score_last_year",
        "avg_total_score_last_year",
        "avg_falls_last_year",
        # "target_clear_element",
        "difficulty",
        # "perfect_element",
        # "q_element",
        # "e_element",
        # "l_element",
        # "ll_element",
        # "h_element",
        # "v_element",
        "element",
        # "attr_element",
        "prev_element",
        # "attr_prev_element",
        "next_element",
        # "attr_next_element",
        "single_element",
        # "clear_prev_element",
        # "clear_next_element",
        "perfect_attr_element",
        "q_attr_element",
        "e_attr_element",
        "l_attr_element",
        "ll_attr_element",
        "h_attr_element",
        "v_attr_element",
        "perfect_attr_prev_element",
        "q_attr_prev_element",
        "e_attr_prev_element",
        "l_attr_prev_element",
        "ll_attr_prev_element",
        "h_attr_prev_element",
        "v_attr_prev_element",
        "perfect_attr_next_element",
        "q_attr_next_element",
        "e_attr_next_element",
        "l_attr_next_element",
        "ll_attr_next_element",
        "h_attr_next_element",
        "v_attr_next_element",
    ]
].copy()
data_e10.shape
# Out:
# (168745, 50)

# %%
data_e10.duplicated(keep="first").sum()
# Out:
# 1509

# %% [markdown]
# ### Разделение данных

# %%
X = data_e10.drop(
    [
        "perfect_attr_element",
        "q_attr_element",
        "e_attr_element",
        "l_attr_element",
        "ll_attr_element",
        "h_attr_element",
        "v_attr_element",
    ],
    axis=1,
)
y = data_e10[
    [
        "perfect_attr_element",
        "q_attr_element",
        "e_attr_element",
        "l_attr_element",
        "ll_attr_element",
        "h_attr_element",
        "v_attr_element",
    ]
]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, shuffle=False, random_state=1206
)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (126558, 43)
# (126558, 7)
# (42187, 43)
# (42187, 7)

# %% [markdown]
# ### Моделирование

# %%
category_columns = [
    # "id",
    # "total_score_id",
    # "title",
    # "decrease",
    # "base_score",
    # "goe",
    # "avg_score",
    # "unit_id",
    # "tournament_id",
    # "base_score_total_scores",
    # "components_score",
    # "total_score",
    # "elements_score",
    # "decreasings_score",
    # "starting_place",
    # "place",
    # "segment_name",
    # "info",
    # "overall_place",
    # "overall_total_score",
    # "overall_place_str",
    "color",
    "school_id",
    # "date_start",
    # "date_end",
    "origin_id",
    # "sequences",
    # "cascade",
    # "title_nlp",
    # "cascade_nlp",
    "multiply",
    # "tournament_duration",
    "start_month",
    "end_month",
    "start_day_of_week",
    "end_day_of_week",
    "start_is_weekend",
    "end_is_weekend",
    "start_season",
    "end_season",
    "tournament_year",
    # "units_with_experience",
    "falls",
    # "components_score_per_element",
    # "custom_base_score",
    # "avg_overall_place_last_year",
    # "avg_overall_total_score_last_year",
    # "avg_components_score_last_year",
    # "avg_place_last_year",
    # "avg_elements_score_last_year",
    # "avg_decreasings_score_last_year",
    # "avg_total_score_last_year",
    # "avg_falls_last_year",
    # "target_clear_element",
    # "difficulty",
    # "perfect_element",
    # "q_element",
    # "e_element",
    # "l_element",
    # "ll_element",
    # "h_element",
    # "v_element",
    "element",
    # "attr_element",
    "prev_element",
    # "attr_prev_element",
    "next_element",
    # "attr_next_element",
    "single_element",
    # "clear_prev_element",
    # "clear_next_element",
    # "perfect_attr_element",
    # "q_attr_element",
    # "e_attr_element",
    # "l_attr_element",
    # "ll_attr_element",
    # "h_attr_element",
    # "v_attr_element",
    "perfect_attr_prev_element",
    "q_attr_prev_element",
    "e_attr_prev_element",
    "l_attr_prev_element",
    "ll_attr_prev_element",
    "h_attr_prev_element",
    "v_attr_prev_element",
    "perfect_attr_next_element",
    "q_attr_next_element",
    "e_attr_next_element",
    "l_attr_next_element",
    "ll_attr_next_element",
    "h_attr_next_element",
    "v_attr_next_element",
]

ohe_columns = [x for x in category_columns if x in X.columns]
scale_columns = [x for x in X.columns if x not in category_columns]

# %%
# Инициализация базового классификатора

base_classifier_e10 = CatBoostClassifier(
    verbose=50,
    n_estimators=50,
    cat_features=category_columns,
    random_state=RANDOM_STATE,
)

# Инициализация мультилейбл классификатора
multi_target_classifier_e10 = MultiOutputClassifier(base_classifier_e10, n_jobs=-1)

# Обучение модели
multi_target_classifier_e10.fit(X_train, y_train)
# Out:
# MultiOutputClassifier(estimator=<catboost.core.CatBoostClassifier object at 0x0000026E10931AF0>,
#                       n_jobs=-1)

# %%
X_test["goe"] = results_model_two

# %%
y_pred_multi_target_e10 = multi_target_classifier_e10.predict(X_test)

# %%
y_proba_multi_target_e10 = multi_target_classifier_e10.predict_proba(X_test)

# %%
print(classification_report(y_test, y_pred_multi_target_e10))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90     33340
#            1       0.11      0.01      0.01      2075
#            2       0.25      0.00      0.01       206
#            3       0.38      0.16      0.23      3699
#            4       0.28      0.08      0.13      1712
#            5       0.17      0.18      0.17      1137
#            6       0.17      0.17      0.17       461
#
#    micro avg       0.81      0.75      0.78     42630
#    macro avg       0.32      0.22      0.23     42630
# weighted avg       0.73      0.75      0.73     42630
#  samples avg       0.75      0.76      0.75     42630
# c:\Users\filat\Documents\projects\my_champion_app\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
hamming_loss_score = hamming_loss(y_test, y_pred_multi_target_e10)
print(f"Hamming Loss: {hamming_loss_score}")
# Out:
# Hamming Loss: 0.061677768032806314

# %% [markdown]
# Показатели ухудшились. Необходимо улучшать качество предыдущих моделей.

# %% [markdown]
# Сохраним модель для использования.

# %%
# joblib.dump(multi_target_classifier_e8, '../models/model_three.joblib')
# Out:
# ['temp/model_three.joblib']
